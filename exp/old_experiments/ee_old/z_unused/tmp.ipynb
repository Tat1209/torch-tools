# %%
import matplotlib.pyplot as plt


plt.xscale("log")

x = [11227812, 22455624, 44911248, 89822496, 179644992, 269467488]	
y = [0.4944, 0.5229, 0.5576, 0.5775, 0.6016, 0.6065]
plt.plot(x, y, marker = ".", label="64")

x = [5995140, 11990280, 23980560, 47961120]
y = [0.4204, 0.4556, 0.4938, 0.5167]
plt.plot(x, y, marker = ".", label="32")

x = [714996, 1429992, 2859984, 5719968, 11439936, 22879872, 45759744, 91519488]
y = [0.3909, 0.4254, 0.4527, 0.4901, 0.5073, 0.5142, 0.5279, 0.5399]
plt.plot(x, y, marker = ".", label="16")

x = [183212, 366424, 732848, 1465696, 2931392, 5862784, 11725568, 23451136]
y = [0.3039, 0.3602, 0.4147, 0.4677, 0.4784, 0.4981, 0.5178, 0.5287]
plt.plot(x, y, marker = ".", label="8")

x = [48072, 96144, 192288, 384576, 769152, 1538304, 3076608, 6153216]
y = [0.2008, 0.2701, 0.3252, 0.395, 0.4342, 0.4577, 0.4895, 0.5399]
plt.plot(x, y, marker = ".", label="4")

x = [31350, 62700, 125400, 250800, 501600, 1003200, 2006400, 4012800, 8025600]
y = [0.111, 0.2015, 0.2419, 0.3114, 0.3526, 0.3814, 0.412, 0.447, 0.4724]
plt.plot(x, y, marker = ".", label="2")

plt.legend()
